# %% [markdown]
# <img src="Images/KNToosi.jpg">
#
# # Digital Image Processing
# ## Third Computer Assignment
# ### Amirhosein Najafi (I)
# ### Student ID : 40112894
# ### Professor : Dr. Abrishami (II)
#
# #### I : a.najafi@email.kntu.ac.ir
# #### II : moghadam@eetd.kntu.ac.ir

# %% [markdown]
# <hr>
#
# ### 5. Spatial Filtering – Edge Detection

# %% [markdown]
# #### a. Load and Display Image

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage import exposure
from scipy.ndimage import median_filter
from scipy.ndimage import uniform_filter
from scipy.ndimage import gaussian_filter

# %%
co = cv2.imread('Images/chessboard.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(co, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# #### b. Spatial Filtering:
